# %%
event = [{'payload': {'key': 'TmV0ZmxpeA==', 'value': '{data=[[1995.0, The Brothers McMullen, 1705950138731, 1265806], [2001.0, Arjuna: Complete Collection, 1705950138731, 1265806], [2001.0, Virgil Bliss, 1705950138731, 1265806], [1990.0, A Cry in the Wild, 1705950138731, 1265806], [2001.0, He Died with a Felafel in His Hand, 1705950138731, 1265806], [2002.0, Stricken, 1705950138731, 1265806], [1992.0, Little Nemo: Adventures in Slumberland, 1705950138731, 1265806], [2002.0, The Next Big Thing, 1705950138731, 1265806], [1999.0, Thicker than Water, 1705950138731, 1265806], [1999.0, All About My Mother, 1705950138731, 1265806]], columns=[YearRelease, Name, current_time, customerID], index=[2533, 396, 10727, 3931, 773, 11269, 14025, 2626, 7337, 9242]}', 'timestamp': 1705950138823, 'topic': 'netflix', 'partition': 0, 'offset': 8}}]

# %%
event[0]['payload']['value']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dict(event[0]['payload']['value'])
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required

# %%
import pandas as pd

data = pd.read_json(event[0]['payload']['value'], orient="split")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 3
#       1 import pandas as pd
# ----> 3 data = pd.read_json(event[0]['payload']['value'], orient="split")
#
# File ~/Documents/Jedha/.venv/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/Documents/Jedha/.venv/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/Documents/Jedha/.venv/lib/python3.11/site-packages/pandas/io/json/_json.py:757, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     754     return json_reader
#     756 with json_reader:
# --> 757     return json_reader.read()
#
# File ~/Documents/Jedha/.venv/lib/python3.11/site-packages/pandas/io/json/_json.py:915, in JsonReader.read(self)
#     913         obj = self._get_object_parser(self._combine_lines(data_lines))
#     914 else:
# --> 915     obj = self._get_object_parser(self.data)
#     916 self.close()
#     917 return obj
#
# File ~/Documents/Jedha/.venv/lib/python3.11/site-packages/pandas/io/json/_json.py:937, in JsonReader._get_object_parser(self, json)
#     935 obj = None
#     936 if typ == "frame":
# --> 937     obj = FrameParser(json, **kwargs).parse()
#     939 if typ == "series" or obj is None:
#     940     if not isinstance(dtype, bool):
#
# File ~/Documents/Jedha/.venv/lib/python3.11/site-packages/pandas/io/json/_json.py:1064, in Parser.parse(self)
#    1062     self._parse_numpy()
#    1063 else:
# -> 1064     self._parse_no_numpy()
#    1066 if self.obj is None:
#    1067     return None
#
# File ~/Documents/Jedha/.venv/lib/python3.11/site-packages/pandas/io/json/_json.py:1326, in FrameParser._parse_no_numpy(self)
#    1320     self.obj = DataFrame(
#    1321         loads(json, precise_float=self.precise_float), dtype=None
#    1322     )
#    1323 elif orient == "split":
#    1324     decoded = {
#    1325         str(k): v
# -> 1326         for k, v in loads(json, precise_float=self.precise_float).items()
#    1327     }
#    1328     self.check_keys_split(decoded)
#    1329     self.obj = DataFrame(dtype=None, **decoded)
#
# ValueError: Expected object or value

# %%
import mlflow
import mlflow.pyfunc

model_name = "Netflix_reco"
alias = "champion"

mlflow.set_tracking_uri("https://mlflowjedhalead-a7146c8dff2f.herokuapp.com/")
recommander = mlflow.pyfunc.load_model(f"models:/{model_name}@{alias}")
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[1], line 8
#       5 alias = "champion"
#       7 mlflow.set_tracking_uri("https://mlflowjedhalead-a7146c8dff2f.herokuapp.com/")
# ----> 8 recommander = mlflow.pyfunc.load_model(f"models:/{model_name}@{alias}")
#
# File ~/Documents/Jedha/.venv/lib/python3.11/site-packages/mlflow/pyfunc/__init__.py:652, in load_model(model_uri, suppress_warnings, dst_path, model_config)
#     618 def load_model(
#     619     model_uri: str,
#     620     suppress_warnings: bool = False,
#     621     dst_path: Optional[str] = None,
#     622     model_config: Optional[Dict[str, Any]] = None,
#     623 ) -> PyFuncModel:
#     624     """
#     625     Load a model stored in Python function format.
#     626
#    (...)
#     650                                              release without warning.
#     651     """
# --> 652     local_path = _download_artifact_from_uri(artifact_uri=model_uri, output_path=dst_path)
#     654     if not suppress_warnings:
#     655         _warn_dependency_requirement_mismatches(local_path)
#
# File ~/Documents/Jedha/.venv/lib/python3.11/site-packages/mlflow/tracking/artifact_utils.py:100, in _download_artifact_from_uri(artifact_uri, output_path)
#      94 """
#      95 :param artifact_uri: The *absolute* URI of the artifact to download.
#      96 :param output_path: The local filesystem path to which to download the artifact. If unspecified,
#      97                     a local output path will be created.
#      98 """
#      99 root_uri, artifact_path = _get_root_uri_and_artifact_path(artifact_uri)
# --> 100 return get_artifact_repository(artifact_uri=root_uri).download_artifacts(
#     101     artifact_path=artifact_path, dst_path=output_path
#     102 )
#
# File ~/Documents/Jedha/.venv/lib/python3.11/site-packages/mlflow/store/artifact/models_artifact_repo.py:178, in ModelsArtifactRepository.download_artifacts(self, artifact_path, dst_path)
#     159 """
#     160 Download an artifact file or directory to a local directory if applicable, and return a
#     161 local path for it.
#    (...)
#     173 :return: Absolute path of the local filesystem location containing the desired artifacts.
#     174 """
#     176 from mlflow.models.model import MLMODEL_FILE_NAME
# --> 178 model_path = self.repo.download_artifacts(artifact_path, dst_path)
#     179 # NB: only add the registered model metadata iff the artifact path is at the root model
#     180 # directory. For individual files or subdirectories within the model directory, do not
#     181 # create the metadata file.
#     182 if os.path.isdir(model_path) and MLMODEL_FILE_NAME in os.listdir(model_path):
#
# File ~/Documents/Jedha/.venv/lib/python3.11/site-packages/mlflow/store/artifact/artifact_repo.py:189, in ArtifactRepository.download_artifacts(self, artifact_path, dst_path)
#     187 # Submit download tasks
#     188 futures = {}
# --> 189 if self._is_directory(artifact_path):
#     190     for file_info in self._iter_artifacts_recursive(artifact_path):
#     191         if file_info.is_dir:  # Empty directory
#
# File ~/Documents/Jedha/.venv/lib/python3.11/site-packages/mlflow/store/artifact/artifact_repo.py:92, in ArtifactRepository._is_directory(self, artifact_path)
#      91 def _is_directory(self, artifact_path):
# ---> 92     listing = self.list_artifacts(artifact_path)
#      93     return len(listing) > 0
#
# File ~/Documents/Jedha/.venv/lib/python3.11/site-packages/mlflow/store/artifact/s3_artifact_repo.py:199, in S3ArtifactRepository.list_artifacts(self, path)
#     197 paginator = s3_client.get_paginator("list_objects_v2")
#     198 results = paginator.paginate(Bucket=bucket, Prefix=prefix, Delimiter="/")
# --> 199 for result in results:
#     200     # Subdirectories will be listed as "common prefixes" due to the way we made the request
#     201     for obj in result.get("CommonPrefixes", []):
#     202         subdir_path = obj.get("Prefix")
#
# File ~/Documents/Jedha/.venv/lib/python3.11/site-packages/botocore/paginate.py:269, in PageIterator.__iter__(self)
#     267 self._inject_starting_params(current_kwargs)
#     268 while True:
# --> 269     response = self._make_request(current_kwargs)
#     270     parsed = self._extract_parsed_response(response)
#     271     if first_request:
#     272         # The first request is handled differently.  We could
#     273         # possibly have a resume/starting token that tells us where
#     274         # to index into the retrieved page.
#
# File ~/Documents/Jedha/.venv/lib/python3.11/site-packages/botocore/paginate.py:357, in PageIterator._make_request(self, current_kwargs)
#     356 def _make_request(self, current_kwargs):
# --> 357     return self._method(**current_kwargs)
#
# File ~/Documents/Jedha/.venv/lib/python3.11/site-packages/botocore/client.py:535, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     531     raise TypeError(
#     532         f"{py_operation_name}() only accepts keyword arguments."
#     533     )
#     534 # The "self" in this scope is referring to the BaseClient.
# --> 535 return self._make_api_call(operation_name, kwargs)
#
# File ~/Documents/Jedha/.venv/lib/python3.11/site-packages/botocore/client.py:983, in BaseClient._make_api_call(self, operation_name, api_params)
#     979     error_code = error_info.get("QueryErrorCode") or error_info.get(
#     980         "Code"
#     981     )
#     982     error_class = self.exceptions.from_code(error_code)
# --> 983     raise error_class(parsed_response, operation_name)
#     984 else:
#     985     return parsed_response
#
# ClientError: An error occurred (InvalidAccessKeyId) when calling the ListObjectsV2 operation: The AWS Access Key Id you provided does not exist in our records.
